# %%
import pandas as pd

# %%
renwu = pd.read_excel('G:/1-规划/崔开通崔可研规划/2020年任务清单/20200924/2020年任务清单（场景+MR）0917YC-打标0924.xlsx')

# %%
slsw = pd.read_excel('G:/1-规划/崔开通崔可研规划/2020年任务清单/四轮十维/20200921/2万多小区的方案.xlsx',sheet_name='Sheet1')

# %%
def fc(renwu,slsw,cj='居民区',ds='武汉',dsy=False):
    data = renwu.loc[renwu['优化']=='优化']
    dataj = renwu.loc[renwu['催开']=='催开']
    dataj=dataj.sort_values('催开完成')
    y_slsw = slsw.loc[slsw['最终方案']=='优化']
    j_slsw = slsw.loc[slsw['最终方案']=='建设']
    if dsy:
        data = data.loc[data['地市']==ds]
        dataj = dataj.loc[dataj['地市']==ds]
        y_slsw = y_slsw.loc[y_slsw['地市']==ds]
        j_slsw = j_slsw.loc[j_slsw['地市']==ds]
        slsw = slsw.loc[slsw['地市']==ds]
    if cj in ['居民区','高校','风景区','医院']:
        y_zong,y_wancheng = data.loc[data['场景']==cj].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['场景']==cj].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj)&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj)&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj)&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})

    elif cj =='城区':
        y_zong,y_wancheng = data.loc[data['9月增补场景-核心城区']=='是'].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['9月增补场景-核心城区']=='是'].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        print(j_zong,j_wancheng)
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['城区/农村']==cj].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['城区/农村']==cj].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['城区/农村']==cj)&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['城区/农村']==cj)&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['城区/农村']==cj)&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})

    elif cj == '农村':
        y_zong,y_wancheng = data.loc[data['9月增补场景-农村']=='是'].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['9月增补场景-农村']=='是'].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['城区/农村']==cj].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['城区/农村']==cj].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['城区/农村']==cj)&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['城区/农村']==cj)&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['城区/农村']==cj)&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    elif cj == '交通枢纽':
        y_zong,y_wancheng = data.loc[data['9月增补场景-交通枢纽']=='是'].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['9月增补场景-交通枢纽']=='是'].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj)&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj)&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']==cj)&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    elif cj in ['宏站','室分']:
        y_zong,y_wancheng = data.loc[data['覆盖类型']==cj].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['覆盖类型']==cj].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['宏站/室分']==cj].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['宏站/室分']==cj].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['宏站/室分']==cj)&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['宏站/室分']==cj)&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['宏站/室分']==cj)&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    elif cj =='4G覆盖率劣于竞对小区占比-电信(%)':
        y_zong,y_wancheng = data.loc[data['电信黑点']==1].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['电信黑点']==1].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['竞对黑点-电信']=='电信'].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['竞对黑点-电信']=='电信'].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['竞对黑点-电信']=='电信')&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['竞对黑点-电信']=='电信')&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['竞对黑点-电信']=='电信')&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    elif cj =='4G覆盖率劣于竞对小区占比-联通(%)':
        y_zong,y_wancheng = data.loc[data['联通黑点']==1].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['联通黑点']==1].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['竞对黑点-联通']=='联通'].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['竞对黑点-联通']=='联通'].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['竞对黑点-联通']=='联通')&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['竞对黑点-联通']=='联通')&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['竞对黑点-联通']=='联通')&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    elif cj =='高校覆盖劣于竞对小区占比-电信(%)':
        y_zong,y_wancheng = data.loc[(data['电信黑点']==1)&(data['场景']=='高校')].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[(dataj['电信黑点']==1)&(dataj['场景']=='高校')].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[(y_slsw['竞对黑点-电信']=='电信')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[(j_slsw['竞对黑点-电信']=='电信')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['竞对黑点-电信']=='电信')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['竞对黑点-电信']=='电信')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['竞对黑点-电信']=='电信')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    elif cj =='高校覆盖劣于竞对小区占比-联通(%)':
        y_zong,y_wancheng = data.loc[(data['联通黑点']==1)&(data['场景']=='高校')].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[(dataj['联通黑点']==1)&(dataj['场景']=='高校')].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        y2_zong,y2_wancheng = y_slsw.loc[(y_slsw['竞对黑点-联通']=='联通')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[(j_slsw['竞对黑点-联通']=='联通')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['竞对黑点-联通']=='联通')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['竞对黑点-联通']=='联通')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['竞对黑点-联通']=='联通')&(y_slsw['场景类型（高校/居民区/风景区/医院/交通枢纽）']=='高校')&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    elif cj =='全网':
        y_zong,y_wancheng = data.loc[data['全网']=='全网'].agg({'唯一编号':'count','优化完成':'count'})
        j_zong,j_wancheng = dataj.loc[dataj['全网']=='全网'].drop_duplicates('TDL规划站号（新）').agg({'唯一编号':'count','催开完成':'count'})
        print(j_zong,j_wancheng)
        y2_zong,y2_wancheng = y_slsw.loc[y_slsw['全网']=='全网'].agg({'小区CGI(*)':'count','最终完成':'count'})
        j2_zong,j2_wancheng = j_slsw.loc[j_slsw['全网']=='全网'].drop_duplicates('规划站号').agg({'小区CGI(*)':'count','最终完成':'count'})
        kd_zong,kd_wancheng = slsw.loc[(slsw['全网']=='全网')&(slsw['最终方案']=='空洞')].agg({'小区CGI(*)':'count','最终完成':'count'})
        d3_zong,d3_wancheng = slsw.loc[(slsw['全网']=='全网')&(slsw['最终方案']=='反开3d')].agg({'小区CGI(*)':'count','最终完成':'count'})
        lg_zong,lg_wancheng = slsw.loc[(slsw['全网']=='全网')&(slsw['最终方案']=='零购')].agg({'小区CGI(*)':'count','最终完成':'count'})
    return (y_wancheng,j_wancheng,y2_zong,y2_wancheng,j2_zong,j2_wancheng,kd_zong,kd_wancheng,d3_zong,d3_wancheng,lg_zong,lg_wancheng)

# %%
# dic_my = dict()
# list_my  = ['宏站','室分','城区','农村','高校覆盖劣于竞对小区占比-电信(%)','高校覆盖劣于竞对小区占比-联通(%)','高校','居民区','风景区','医院',
#            '交通枢纽','4G覆盖率劣于竞对小区占比-电信(%)','4G覆盖率劣于竞对小区占比-联通(%)']
# for name in list_my:
#     y_wancheng,j_wancheng,y2_zong,y2_wancheng,j2_zong,j2_wancheng,kd_zong,kd_wancheng,d3_zong,d3_wancheng,lg_zong,lg_wancheng = fc(name)
#     res = f' {name}进度=>优化:{y2_wancheng+y_wancheng}/{y_wancheng+y2_zong},剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}单；\n \
# 建设：{kd_wancheng+j2_wancheng}/{j_wancheng+j2_zong},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}单。 \
# 空洞：{kd_wancheng}/{kd_zong},剩余{kd_zong-kd_wancheng}\n \
# 3D反开：{d3_wancheng}/{d3_zong},剩余{d3_zong-d3_wancheng}\n \
# 零购：{lg_wancheng}/{lg_zong},剩余{lg_zong - lg_wancheng}'
#     dic_my[name] = res

# %%
guihua_nc='''3、规划：结合投诉及MR大数据分析，挖掘全网农村问题区域，精准规划站点。'''
youhua_str='''\na、每月新增宏站弱覆盖小区纳入集中优化；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决；
c、跟踪推动新建站点进度，提升弱覆盖区域网络覆盖率；
d、通过MR自动化工具分析导致的覆盖质差TOP小区的优化解决方案，建立优化清单表进行闭环跟踪；'''
youhua_str_cq='''\na、每月新增城区弱覆盖小区纳入集中优化；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决；
c、跟踪推动新建站点进度，提升弱覆盖区域网络覆盖率；
d、通过MR自动化工具分析导致的覆盖质差TOP小区的优化解决方案，建立优化清单表进行闭环跟踪；'''
jianshe_yy='''\na、建立催开医院重点站点清单，对地市实行一对一帮扶，优先开展医院站点催开通专项工作；
b、升级站点覆盖能力仿真工具，指导选择站点建设方案；
c、站点开通情况纳入每月集中规划月报，对开通进度较慢地市进行通报。
3、规划：
a、分析医院4G小区流量及投诉大数据，进行精准站点资源规划。'''
jianshe_str = '''\na、持续进行重点站催开通专项工作；
b、持续对地市重、难站点进行现场帮扶。'''
jianshe_fjq='''\na、持续推动已纳入“7734”问题小区解决工作；
b、持续进行重点站催开通专项工作；
c、持续对地市重、难站点进行现场帮扶。'''
jianshe_jd_qw='''\na、持续进行重点站催开通专项工作；
b、结合MRO数据对重点场景黑点进行需求挖掘，对于长期竞对黑点区域优先投入建设；对疑难选址问题点进行一对一帮扶。'''
jianshe_jd='''\na、持续进行重点站催开通专项工作；
b、结合MRO数据对重点场景黑点进行需求挖掘，对于长期竞对黑点区域优先投入建设；'''
qita1='''PADS、LTE小基站试点工作当前已完成，预计后续进行中心内部评审后向计划部汇报，这两种新型建设方案补充至零购工程并安排后期招标与采购。'''
qita='''6、PADS、LTE小基站试点工作当前已完成，预计后续进行中心内部评审后向计划部汇报，这两种新型建设方案补充至零购工程并安排后期招标与采购。
7、后续明年将有专项搬迁工程项目补盲。'''
qita56='''5、PADS、LTE小基站试点工作当前已完成，预计后续进行中心内部评审后向计划部汇报，这两种新型建设方案补充至零购工程并安排后期招标与采购。
6、后续明年将有专项搬迁工程项目补盲。'''
qita78='''7、PADS、LTE小基站试点工作当前已完成，预计后续进行中心内部评审后向计划部汇报，这两种新型建设方案补充至零购工程并安排后期招标与采购。
8、后续明年将有专项搬迁工程项目补盲。'''
qita67='''6、PADS、LTE小基站试点工作当前已完成，预计后续进行中心内部评审后向计划部汇报，这两种新型建设方案补充至零购工程并安排后期招标与采购。
7、后续明年将有专项搬迁工程项目补盲。'''
qita_nc='''7、后续明年将有专项搬迁工程项目补盲。'''
youhua_jd_qw='''\na、每月新增竞对黑点小区纳入集中优化；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决；
c、通过MR竞对分析，建立问题清单列出TOP小区进行优化调整，定期通报各地市优化进度；'''
youhua_jtsn='''\na、每月对交通枢纽新增弱覆盖小区纳入集中优化；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决；
c、由于交通枢纽用户量波动较大（如周末、假期等），实时监控网络质量及覆盖状况，定期专人现场摸底测试、优化调整，建立问题明细表并跟踪闭环；
d、汇总综合平台数据、MR数据采集、投诉清单及市场口反馈等数据分析加大优化进度及优化效果，提升网络覆盖率；'''
youhua_jmq='''\n针对我省居民区MR覆盖率指标排名相对靠后问题，优化具体工作推动如下：
1）加大F900优化调整力度，联合优化部进行T/F均衡专项优化；
2）加大重点站点督办力度，275个站点在7734督办清单，依托7734专项重点督办。剩余站点后续开展地市调研，建立重点站清单，对地市实行一对一帮扶；
3）加强优化工单实施效果监管力度，及时通报相关进度；'''
youhua_yy='''\n医院优化具体工作推动如下：
a、督促推动地市公司加快医院MR弱覆盖小区优化提升工作进度；
b、根据FDD站点开通进度，对可TF协同优化的医院弱覆盖小区及时优化解决；
c、结合投诉清单及市场口反馈对影响用户感知重要医院强化优化进度及优化效果。'''
youhua_gx = '''\n1）加大重点站点督办力度，275个站点在7734督办清单，依托7734专项重点督办。剩余站点后续开展地市调研，建立重点站清单，对地市实行一对一帮扶；
2）加强高校优化工单实施效果监管力度，及时通报相关进度；
3）每月对高校新增弱覆盖小区纳入集中优化，跟踪地市公司优化问题解决率；'''
youhua_fjq='''\na、每月对景区新增弱覆盖小区纳入集中优化，建立问题明细表，跟踪地市公司优化问题解决率定期进度通报；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决;
c、通过MR数据、网管数据分析、网管质差TOP小区分析，针对性解决对应小区覆盖问题；'''
youhua_jd='''\na、每月新增竞对黑点小区纳入集中优化；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决；
c、督促分公司进行黑点专项整治，提升地市竞对优化水平；
d、通过MR竞对分析，建立问题清单列出TOP小区进行优化调整，定期通报各地市优化进度；'''
youhua_sf='''\na、每月对室分新增弱覆盖小区纳入集中优化；
b、加强室内外协同专项整治；
c、通过平台小区数据和用户投诉工单以及MR覆盖率分析室分弱覆盖原因，提升优化效果，如：室内分布不合理需推动整改和站点故障需推动故障处理等；
d、推动室分新建站点进度，提升室内网络覆盖强度；'''
youhua_cq = '''\na、每月新增宏站弱覆盖小区纳入集中优化；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决；
c、跟踪推动新建站点进度，提升弱覆盖区域网络覆盖率；
d、通过MR自动化工具分析导致的覆盖质差TOP小区的优化解决方案，建立优化清单表进行闭环跟踪；'''
youhua_nc='''\n针对农村区域MR覆盖率指标排名相对靠后问题，优化具体工作推动如下：
a、每月对农村区新增弱覆盖小区纳入集中优化，跟踪地市公司优化问题闭环解决率；
b、根据FDD站点开通进度，对可TF协同优化的弱覆盖小区及时优化解决；
c、通过农村区占用小区明细匹配，MR指标采集，网管TA数据分析和小区业务量及容量分析，优化站点覆盖区域，如：方位角和下倾角调整、功率提升（对功率受限小区，无线资源利用率较低的前提下可通过压缩带宽提升功率手段）提升网络覆盖率；'''

# %%
y_wancheng,j_wancheng,y2_zong,y2_wancheng,j2_zong,j2_wancheng,kd_zong,kd_wancheng,d3_zong,d3_wancheng,lg_zong,lg_wancheng

# %%
ds_shiyong = False
dic_my = dict()
# list_my  = ['宏站','室分','城区','农村','高校覆盖劣于竞对小区占比-电信(%)','高校覆盖劣于竞对小区占比-联通(%)','高校','居民区','风景区','医院',
#            '交通枢纽','4G覆盖率劣于竞对小区占比-电信(%)','4G覆盖率劣于竞对小区占比-联通(%)','全网']
list_my  = ['全网']
city = ['恩施','鄂州','黄冈','黄石','江汉','荆门','荆州','潜江','十堰','随州','武汉','孝感','咸宁','宜昌','天门','襄阳']
if ds_shiyong:
    for city1 in city:
        for name in list_my:
            y_wancheng,j_wancheng,y2_zong,y2_wancheng,j2_zong,j2_wancheng,kd_zong,kd_wancheng,d3_zong,d3_wancheng,lg_zong,lg_wancheng = fc(renwu,slsw,name,city1,ds_shiyong)
            if name == '宏站':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_str} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                    \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                    \n5、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita}'
                dic_my[city1+name] = res
            elif name == '室分':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_sf} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                    \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n4、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n5、{qita1}'
                dic_my[city1+name] = res
            elif name == '城区':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_str_cq} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                    \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                    \n5、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita}'
                dic_my[city1+name] = res
            elif name == '农村':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_nc} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                    \n{guihua_nc}\n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                    \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita_nc}'
                dic_my[city1+name] = res
            elif name in ['高校覆盖劣于竞对小区占比-电信(%)','高校覆盖劣于竞对小区占比-联通(%)']:
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jd} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_jd} \
                    \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n5、{qita1}'
                dic_my[city1+name] = res
            elif name == '高校':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_gx} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                    \n3、规划：\na、利用高校POI（高校边界）数据挖掘手段，关联高校4G覆盖小区及覆盖率情况，指导精准规划，提升问题高校覆盖能力。 \
                    \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n{qita}'
                dic_my[city1+name] = res
            elif name == '居民区':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jmq} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                    \n3、规划：\na、利用高校POI（高校边界）数据挖掘手段，关联高校4G覆盖小区及覆盖率情况，指导精准规划，提升问题高校覆盖能力。 \
                    \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                    \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita78}'
                dic_my[city1+name] = res
            elif name == '风景区':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_fjq} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_fjq} \
                    \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n{qita56}'
                dic_my[city1+name] = res
            elif name == '交通枢纽':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jtsn} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                    \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n{qita56}'
                dic_my[city1+name] = res
            elif name in ['4G覆盖率劣于竞对小区占比-电信(%)','4G覆盖率劣于竞对小区占比-联通(%)']:
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jd_qw} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_jd_qw} \
                    \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                    \n5、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita67}'
                dic_my[city1+name] = res
            elif name =='医院':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_yy} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_yy} \
                    \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                    \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita78}'
                dic_my[city1+name] = res
            elif name =='全网':
                res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_yy} \
                    \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_yy} \
                    \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                    \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                    \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita78}'
                dic_my[city1+name] = res
else:
    for name in list_my:
        y_wancheng,j_wancheng,y2_zong,y2_wancheng,j2_zong,j2_wancheng,kd_zong,kd_wancheng,d3_zong,d3_wancheng,lg_zong,lg_wancheng = fc(renwu,slsw,name)
        if name == '宏站':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_str} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                \n5、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita}'
            dic_my[name] = res
        elif name == '室分':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_sf} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n4、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n5、{qita1}'
            dic_my[name] = res
        elif name == '城区':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_str_cq} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                \n5、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita}'
            dic_my[name] = res
        elif name == '农村':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_nc} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                \n{guihua_nc}\n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita_nc}'
            dic_my[name] = res
        elif name in ['高校覆盖劣于竞对小区占比-电信(%)','高校覆盖劣于竞对小区占比-联通(%)']:
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jd} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_jd} \
                \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n5、{qita1}'
            dic_my[name] = res
        elif name == '高校':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_gx} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                \n3、规划：\na、利用高校POI（高校边界）数据挖掘手段，关联高校4G覆盖小区及覆盖率情况，指导精准规划，提升问题高校覆盖能力。 \
                \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n{qita}'
            dic_my[name] = res
        elif name == '居民区':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jmq} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                \n3、规划：\na、利用高校POI（高校边界）数据挖掘手段，关联高校4G覆盖小区及覆盖率情况，指导精准规划，提升问题高校覆盖能力。 \
                \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita78}'
            dic_my[name] = res
        elif name == '风景区':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_fjq} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_fjq} \
                \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n{qita56}'
            dic_my[name] = res
        elif name == '交通枢纽':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jtsn} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_str} \
                \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。\n{qita56}'
            dic_my[name] = res
        elif name in ['4G覆盖率劣于竞对小区占比-电信(%)','4G覆盖率劣于竞对小区占比-联通(%)']:
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_jd_qw} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_jd_qw} \
                \n3、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n4、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                \n5、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita67}'
            dic_my[name] = res
        elif name =='医院':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_yy} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_yy} \
                \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita78}'
            dic_my[name] = res
        elif name =='全网':
            res = f'1、优化：累计优化完成：{y2_wancheng+y_wancheng}个小区,剩余{(y_wancheng+y2_zong)-(y2_wancheng+y_wancheng)}个小区待派发，随周粒度优化工单进行派发；{youhua_yy} \
                \n2、建设：累计建设完成：{j_wancheng+j2_wancheng},剩余{(j_wancheng+j2_zong)-(j_wancheng+j2_wancheng)}个规划站点待开通。{jianshe_yy} \
                \n4、覆盖空洞：累计空洞完成：{kd_wancheng}个,剩余{kd_zong-kd_wancheng}个空洞待解决。 \
                \n5、5G站点反开3D-MIMO进行补充覆盖。5G站点已经反开3D站点{d3_wancheng}个,剩余{d3_zong-d3_wancheng}个待完成。 \
                \n6、零购项目申请{lg_zong}个，目前已经完成{lg_wancheng}个\n{qita78}'
            dic_my[name] = res

# %%
res = pd.DataFrame.from_dict(dic_my,orient='index',columns=['进度']).reset_index()

# %%
res.to_clipboard(index=False)
